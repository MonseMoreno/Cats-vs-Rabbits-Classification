# %%
#### IMPORTS

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
#### PREDICCIÓN DE MODELO BINARIO

# Cargar el modelo
model = load_model('tercer_modelo.h5')

# Ruta de la imagen
img_path = 'assets/Predicciones/4.jpg'

# Preprocesamiento
img = image.load_img(img_path, target_size=(150, 150))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predicción
prediction = model.predict(img_array)[0][0]
prob_conejo = prediction * 100
prob_gato = (1 - prediction) * 100


# Mostrar resultado
plt.imshow(img)
plt.axis('off')
plt.title(f'Gato: {prob_gato:.2f}%  |  Conejo: {prob_conejo:.2f}%')
plt.show()

# %%
#### PREDICCIÓN DE MODELO CON TRES CLASES

# Cargar el modelo
model = load_model('EF_modelo.h5')

# Ruta de la imagen
img_path = 'assets/Predicciones/2.jpeg'

# Preprocesamiento
img = image.load_img(img_path, target_size=(150, 150))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Predicción
prediction = model.predict(img_array)[0]

# Nombres de clases
class_names = ['cat', 'dog', 'rabbit']

# Obtener índice y valor máximo
predicted_index = np.argmax(prediction)
predicted_class = class_names[predicted_index]
predicted_confidence = prediction[predicted_index] * 100

# Mostrar resultado
plt.imshow(img)
plt.axis('off')
#title = ' | '.join([f'{class_names[i].capitalize()}: {prediction[i] * 100:.2f}%' for i in range(3)])
plt.title(f'{predicted_class.capitalize()}: {predicted_confidence:.2f}%')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
